# %% [markdown]
# # Exercise 1A: Create a string made of the first, middle and last character
# Write a program to create a new string made of an input string’s first, middle, and last character.

# %%
x="Yash"
y=x[0] + x[round((len(x))/2)] + x[len(x)-1]
y
# Out:
# 'Ysh'

# %% [markdown]
# # Exercise 1B: Create a string made of the middle three characters
# Write a program to create a new string made of the middle three characters of an input string.

# %%
x='dagfsfb'
mid=round(len(x)/2)
x[mid-1:mid+2]
# Out:
# 'fsf'

# %% [markdown]
# # Exercise 2: Append new string in the middle of a given string
# Given two strings, s1 and s2. Write a program to create a new string s3 by appending s2 in the middle of s1.

# %%
s1='asdf'
s2='qwert'
mid=round(len(s1)/2)
s3=s1[:mid] + s2 + s1[mid:]
s3
# Out:
# 'asqwertdf'

# %% [markdown]
# # Exercise 3: Create a new string made of the first, middle, and last characters of each input string
# Given two strings, s1 and s2, write a program to return a new string made of s1 and s2’s first, middle, and last characters.

# %%
s1='America'
s2='Japan'
mid=round((len(s1))/2)-11
mid1=round(len(s2)/2)
s3=s1[0]+s2[0]+s1[mid]+s2[mid1]+s1[(len(s1)-1)]+s2[len(s2)-1]
s3
# Out:
# 'AJApan'

# %% [markdown]
# # Exercise 4: Arrange string characters such that lowercase letters should come first
# Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.

# %%
s1='AsdDFfdgsdFDFsds'
s2=''
for x in s1:
    if x.islower():
        s2+=x
for x in s1:
    if not x.islower():
        s2+=x
s2
# Out:
# 'sdfdgsdsdsADFFDF'

# %% [markdown]
# # Exercise 5: Count all letters, digits, and special symbols from a given string

# %%
s1="hgrd4@r45!^_"
x,y,z=0,0,0
for i in s1:
    if i.isdigit(): x+=1
    elif i.isalpha(): y+=1
    else: z+=1

x,y,z
# Out:
# (3, 5, 4)

# %% [markdown]
# # Exercise 6: Create a mixed String using the following rules
# Given two strings, s1 and s2. Write a program to create a new string s3 made of the first char of s1, then the last char of s2, Next, the second char of s1 and second last char of s2, and so on. Any leftover chars go at the end of the result.

# %%
s1='dfthvhg'
s2='jffcuom'
s3=''
len1=s1 if s1>s2 else s2
s2=s2[::-1]
i=0
while (True):
    if i< len(s1): s3+=s1[i]
    if i< len(s2): s3+=s2[i]
    if i>len(s1) and i>len(s2) : break
    i+=1
    
s3
# Out:
# 'dmfotuhcvfhfgj'

# %% [markdown]
# # Exercise 7: String characters balance Test
# Write a program to check if two strings are balanced. For example, strings s1 and s2 are balanced if all the characters in the s1 are present in s2. The character’s position doesn’t matter.

# %%
s2 = 'asdkuhfbh'
s1 = 'akuhd'
count = 0
for char in s1:
    if char in s2 : count += 1

if count == len(s1) : print("Thanos will be proud!")
# Out:
# Thanos will be proud!

# %% [markdown]
# # Exercise 8: Find all occurrences of a substring in a given string by ignoring the case
# Write a program to find all occurrences of “USA” in a given string ignoring the case.

# %%
s1 = "THE people of USA are self obssessed. Even though the culture of usa is only 300 years old"
s2 = 'usa'
s1 = s1.lower()
arr = s1.split()
count = 0
for item in arr:
    if item == s2 : count += 1
count
# Out:
# 2

# %% [markdown]
# # Exercise 9: Calculate the sum and average of the digits present in a string
# Given a string s1, write a program to return the sum and average of the digits that appear in the string, ignoring all other characters.

# %%
s1 = 'bfdww3432#%y7hu'
sum,count = 0,0
for char in s1:
    if char.isdigit() : 
        sum += int(char) 
        count += 1
sum,sum/count
# Out:
# (19, 3.8)

# %% [markdown]
# # Exercise 10: Write a program to count occurrences of all characters within a string

# %%
s1 = ' sdfkduh 43 @dkd009JYGJd+__&^%$#@'
diction = dict()
count = 0
for char in s1:
    count = s1.count(char)
    diction[char] = count

diction
# Out:
# {' ': 3,
#  's': 1,
#  'd': 5,
#  'f': 1,
#  'k': 2,
#  'u': 1,
#  'h': 1,
#  '4': 1,
#  '3': 1,
#  '@': 2,
#  '0': 2,
#  '9': 1,
#  'J': 2,
#  'Y': 1,
#  'G': 1,
#  '+': 1,
#  '_': 2,
#  '&': 1,
#  '^': 1,
#  '%': 1,
#  '$': 1,
#  '#': 1}

# %% [markdown]
# # Exercise 11: Reverse a given string

# %%
s1 = 'sa,ehrfi 76355d^&&T gudyj'
s1[::-1]
# Out:
# 'jydug T&&^d55367 ifrhe,as'

# %% [markdown]
# # Exercise 12: Find the last position of a given substring
# Write a program to find the last position of a substring “Emma” in a given string.

# %%
s1 = "Emma is a data scientist who knows Python. Emma works at google."
s1.rfind("Emma")
# Out:
# 43

# %% [markdown]
# # Exercise 13: Split a string on hyphens
# Write a program to split a given string on hyphens and display each substring.

# %%
s1 = "Emma-is-a-data-scientist"
arr = s1.split('-')
arr
# Out:
# ['Emma', 'is', 'a', 'data', 'scientist']

# %% [markdown]
# # Exercise 14: Remove empty strings from a list of strings

# %%
sl1 = ["Emma", "Jon", "", "Kelly", None, "Eric", ""]
sl1 = list(filter(None,sl1))
sl1
# Out:
# ['Emma', 'Jon', 'Kelly', 'Eric']

# %% [markdown]
# # Exercise 15: Remove special symbols / punctuation from a string

# %%
from string import punctuation as pn
s1 = "/*Jon is @developer & musician"
# for char in s1:
#     if not char.isalpha(): s1.replace(char,"")
# s1 = "".join([char for char in s1 if (char.isalpha()) or (char==" ")])
s1 = s1.translate(s1.maketrans('','',pn))
s1
# Out:
# 'Jon is developer  musician'

# %% [markdown]
# # Exercise 16: Removal all characters from a string except integers

# %%
s1 = 'I am 25 years and 10 months old'
s1 = "".join([char for char in s1 if char.isdigit()])
s1
# Out:
# '2510'

# %% [markdown]
# # Exercise 17: Find words with both alphabets and numbers

# %%
from string import digits as d
s1 ="Emma25 is Data scientist50 and AI Expert"
arr = s1.split()
for item in arr:
    if any(char.isdigit() for char in item) and any(char.isalpha() for char in item): print(item)
# Out:
# Emma25
# scientist50

# %% [markdown]
# # Exercise 18: Replace each special symbol with # in the following string

# %%
s1 = '/*Jon is @developer & musician!!'
for char in s1:
    if not (char.isdigit() or char.isalpha() or char == " "): s1 = s1.replace(char,"#")
s1
# Out:
# '##Jon is #developer # musician##'
